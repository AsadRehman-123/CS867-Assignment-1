# %%
#mounting google drive in google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/'My Drive'/'Colab Notebooks'/CV/'Assignment 1'/
# Out:
# /content/drive/My Drive/Colab Notebooks/CV/Assignment 1

# %%
#This is the helper file uploaded in Google drive and contain all required function and libraries
# %run myHelperScript.ipynb

# %%
#This function will display image in grey scale as well as histogram of that image
imageGreyWithHistogram("04.jpg")
#This function will apply histogram equalization on grey scale image and display histogram of that image
imageHistogramEqualizer("04.jpg")

# %%
imageGreyWithHistogram("02.jpg")
imageHistogramEqualizer("02.jpg")
